# %% [markdown]
# <a href="https://colab.research.google.com/github/SrivikramMV/CSC2031/blob/main/CSC2034_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

red_wine_df = pd.read_csv("winequality-red.csv")

red_wine_df.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
num_rows, num_cols = red_wine_df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)

missing_values = red_wine_df.isnull().sum()
print("\nMissing values:")
print(missing_values)
# Out:
# Number of rows: 1599
# Number of columns: 1
#
# Missing values:
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    0
# dtype: int64

# %%
red_wine_df = pd.read_csv("winequality-red.csv", delimiter=";")

num_rows, num_cols = red_wine_df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)


missing_values = red_wine_df.isnull().sum()
print("\nMissing values:")
print(missing_values)
# Out:
# Number of rows: 1599
# Number of columns: 12
#
# Missing values:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(data=red_wine_df, x='quality', color='red', label='Red Wine', ax=ax, kde=True)

ax.set_xlabel("Wine Quality")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Wine Quality for Red Wines")

ax.legend()

plt.show()

# %%
white_wine_df = pd.read_csv("winequality-white.csv", delimiter=";")

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(data=white_wine_df, x='quality', color='blue', label='White Wine', ax=ax, kde=True)

ax.set_xlabel("Wine Quality")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Wine Quality for White Wines")

ax.legend()

plt.show()

# %%
red_mean_alcohol = red_wine_df['alcohol'].mean()
red_std_alcohol = red_wine_df['alcohol'].std()

print("Mean alcohol content (red wine):", red_mean_alcohol)
print("Standard deviation of alcohol content (red wine):", red_std_alcohol)

print("-----------------------------------------------------------------------")

low_threshold_red = red_mean_alcohol - red_std_alcohol
high_threshold_red = red_mean_alcohol + red_std_alcohol

print("Low threshold for alcohol content (red wine):", low_threshold_red)
print("High threshold for alcohol content (red wine):", high_threshold_red)
# Out:
# Mean alcohol content (red wine): 10.422983114446529
# Standard deviation of alcohol content (red wine): 1.0656675818473946
# -----------------------------------------------------------------------
# Low threshold for alcohol content (red wine): 9.357315532599134
# High threshold for alcohol content (red wine): 11.488650696293924

# %%
import numpy as np

red_wine_df['alcohol_cat'] = pd.cut(red_wine_df['alcohol'], bins=[-np.inf, low_threshold_red, high_threshold_red, np.inf], labels=['low', 'mid', 'high'])
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality alcohol_cat
# 0      9.4        5         mid
# 1      9.8        5         mid
# 2      9.8        5         mid
# 3      9.8        6         mid
# 4      9.4        5         mid

# %%
white_mean_alcohol = white_wine_df['alcohol'].mean()
white_std_alcohol = white_wine_df['alcohol'].std()

print("Mean alcohol content (white wine):", white_mean_alcohol)
print("Standard deviation of alcohol content (white wine):", white_std_alcohol)

print("-----------------------------------------------------------------------")

low_threshold_white = white_mean_alcohol - white_std_alcohol
high_threshold_white = white_mean_alcohol + white_std_alcohol

print("Low threshold for alcohol content (white wine):", low_threshold_white)
print("High threshold for alcohol content (white wine):", high_threshold_white)
# Out:
# Mean alcohol content (white wine): 10.514267047774602
# Standard deviation of alcohol content (white wine): 1.230620567757318
# -----------------------------------------------------------------------
# Low threshold for alcohol content (white wine): 9.283646480017284
# High threshold for alcohol content (white wine): 11.74488761553192

# %%
white_wine_df['alcohol_cat'] = pd.cut(white_wine_df['alcohol'], bins=[-np.inf, low_threshold_white, high_threshold_white, np.inf], labels=['low', 'mid', 'high'])
white_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality alcohol_cat
# 0      8.8        6         low
# 1      9.5        6         mid
# 2     10.1        6         mid
# 3      9.9        6         mid
# 4      9.9        6         mid

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

sns.histplot(data=red_wine_df, x='quality', hue='alcohol_cat', multiple='stack', ax=axes[0])
axes[0].set_title('Distribution of Wine Quality for Red Wines')
axes[0].set_xlabel('Quality')
axes[0].set_ylabel('Frequency')

sns.histplot(data=white_wine_df, x='quality', hue='alcohol_cat', multiple='stack', ax=axes[1])
axes[1].set_title('Distribution of Wine Quality for White Wines')
axes[1].set_xlabel('Quality')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.histplot(data=red_wine_df, x='residual sugar', color='red', label='Red Wine', kde=True)
sns.histplot(data=white_wine_df, x='residual sugar', color='blue', label='White Wine', kde=True)

plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')
plt.title('Distribution of Residual Sugar for Red and White Wines')

plt.legend()

plt.show()

# %%
from tabulate import tabulate

threshold = 10

red_wine_df['isSweet'] = (red_wine_df['residual sugar'] > threshold).astype(int)
white_wine_df['isSweet'] = (white_wine_df['residual sugar'] > threshold).astype(int)

print("Red Wine Data:")
print(red_wine_df.head())
print("\nWhite Wine Data:")
print(white_wine_df.head())

# Display red wine data
#print("Red Wine Data:")
#print(tabulate(red_wine_df.head(), headers='keys', tablefmt='grid'))

# Display white wine data
#print("\nWhite Wine Data:")
#print(tabulate(white_wine_df.head(), headers='keys', tablefmt='grid'))#
# Out:
# Red Wine Data:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.40              0.70         0.00            1.90       0.08
# 1           7.80              0.88         0.00            2.60       0.10
# 2           7.80              0.76         0.04            2.30       0.09
# 3          11.20              0.28         0.56            1.90       0.07
# 4           7.40              0.70         0.00            1.90       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                11.00                34.00      1.00 3.51       0.56
# 1                25.00                67.00      1.00 3.20       0.68
# 2                15.00                54.00      1.00 3.26       0.65
# 3                17.00                60.00      1.00 3.16       0.58
# 4                11.00                34.00      1.00 3.51       0.56
#
#    alcohol  quality alcohol_cat  isSweet
# 0     9.40        5         mid        0
# 1     9.80        5         mid        0
# 2     9.80        5         mid        0
# 3     9.80        6         mid        0
# 4     9.40        5         mid        0
#
# White Wine Data:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.00              0.27         0.36           20.70       0.04
# 1           6.30              0.30         0.34            1.60       0.05
# 2           8.10              0.28         0.40            6.90       0.05
# 3           7.20              0.23         0.32            8.50       0.06
# 4           7.20              0.23         0.32            8.50       0.06
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                45.00               170.00      1.00 3.00       0.45
# 1                14.00               132.00      0.99 3.30       0.49
# 2                30.00                97.00      1.00 3.26       0.44
# 3                47.00               186.00      1.00 3.19       0.40
# 4                47.00               186.00      1.00 3.19       0.40
#
#    alcohol  quality alcohol_cat  isSweet
# 0     8.80        6         low        1
# 1     9.50        6         mid        0
# 2    10.10        6         mid        0
# 3     9.90        6         mid        0
# 4     9.90        6         mid        0

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=red_wine_df, x='isSweet', y='quality')
plt.title('Red Wine Quality vs Sweetness')
plt.xlabel('Sweetness (0: Dry, 1: Sweet)')
plt.ylabel('Quality')
plt.xticks([0, 1], ['Dry', 'Sweet'])
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(data=white_wine_df, x='isSweet', y='quality')
plt.title('White Wine Quality vs Sweetness')
plt.xlabel('Sweetness (0: Dry, 1: Sweet)')
plt.ylabel('Quality')
plt.xticks([0, 1], ['Dry', 'Sweet'])
plt.show()
